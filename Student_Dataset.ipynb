# %% [markdown]
# # Student Performance & Learning Style
# - Dataset linking study habits, online courses, and exam performance.

# %% [markdown]
# ### import neccessary libraries

# %%
# %matplotlib inline
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
#%matplotlib notebook

# %%
# Load The Dataset
file_path = r"C:\Users\hp\Downloads\archive\student_performance_large_dataset.csv"
df = pd.read_csv(file_path)
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
# Check the first 10 rows of the dataset
df.head(10)
# Out:
#   Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0     S00001   18  Female                    48              Kinesthetic
# 1     S00002   29  Female                    30          Reading/Writing
# 2     S00003   20  Female                    47              Kinesthetic
# 3     S00004   23  Female                    13                 Auditory
# 4     S00005   19  Female                    24                 Auditory
# 5     S00006   28  Female                    26              Kinesthetic
# 6     S00007   19  Female                    49          Reading/Writing
# 7     S00008   27    Male                    14          Reading/Writing
# 8     S00009   22    Male                    45                   Visual
# 9     S00010   28   Other                    35                 Auditory
#
#    Online_Courses_Completed Participation_in_Discussions  \
# 0                        14                          Yes
# ...

# %%
# Check the last 10 rows of the dataset
df.tail(10)
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 9990     S09991   21   Other                    42                 Auditory
# 9991     S09992   28    Male                    26                   Visual
# 9992     S09993   26    Male                    41              Kinesthetic
# 9993     S09994   20    Male                    16              Kinesthetic
# 9994     S09995   28  Female                    42                   Visual
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
#       Online_Courses_Completed Participation_in_Discussions  \
# 9990                        13                           No
# ...

# %%
# Check the columns of the dataset
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Study_Hours_per_Week',
#        'Preferred_Learning_Style', 'Online_Courses_Completed',
#        'Participation_in_Discussions', 'Assignment_Completion_Rate (%)',
#        'Exam_Score (%)', 'Attendance_Rate (%)', 'Use_of_Educational_Tech',
#        'Self_Reported_Stress_Level', 'Time_Spent_on_Social_Media (hours/week)',
#        'Sleep_Hours_per_Night', 'Final_Grade'],
#       dtype='object')

# %%
#Check the shape of the dataset
df.shape
# Out:
# (10000, 15)

# %%
# Check the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Student_ID                               10000 non-null  object
#  1   Age                                      10000 non-null  int64
#  2   Gender                                   10000 non-null  object
#  3   Study_Hours_per_Week                     10000 non-null  int64
#  4   Preferred_Learning_Style                 10000 non-null  object
#  5   Online_Courses_Completed                 10000 non-null  int64
#  6   Participation_in_Discussions             10000 non-null  object
#  7   Assignment_Completion_Rate (%)           10000 non-null  int64
#  8   Exam_Score (%)                           10000 non-null  int64
#  9   Attendance_Rate (%)                      10000 non-null  int64
# ...

# %%
# Check the summary of the dataset
df.isnull().sum()
# Out:
# Student_ID                                 0
# Age                                        0
# Gender                                     0
# Study_Hours_per_Week                       0
# Preferred_Learning_Style                   0
# Online_Courses_Completed                   0
# Participation_in_Discussions               0
# Assignment_Completion_Rate (%)             0
# Exam_Score (%)                             0
# Attendance_Rate (%)                        0
# Use_of_Educational_Tech                    0
# Self_Reported_Stress_Level                 0
# Time_Spent_on_Social_Media (hours/week)    0
# Sleep_Hours_per_Night                      0
# Final_Grade                                0
# dtype: int64

# %%
# Check of duplicated rows in the dataset
df.duplicated().sum()
# Out:
# 0

# %%
# drop the Student ID column if it exists
if 'Student_ID' in df.columns:
	df.drop('Student_ID', axis=1, inplace=True)
df
# Out:
#       Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0      18  Female                    48              Kinesthetic
# 1      29  Female                    30          Reading/Writing
# 2      20  Female                    47              Kinesthetic
# 3      23  Female                    13                 Auditory
# 4      19  Female                    24                 Auditory
# ...   ...     ...                   ...                      ...
# 9995   20    Male                    30                 Auditory
# 9996   23  Female                    16                   Visual
# 9997   26    Male                    23                   Visual
# 9998   18    Male                    41          Reading/Writing
# 9999   24    Male                     8                   Visual
#
#       Online_Courses_Completed Participation_in_Discussions  \
# 0                           14                          Yes
# 1                           20                           No
# ...

# %%
# Check the shape of the dataset after dropping the Student ID column
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# # EDA

# %%
#Check the summary of the dataset
df.describe().T
# Out:
#                                            count     mean        std   min  \
# Age                                      10000.0  23.4788   3.461986  18.0
# Study_Hours_per_Week                     10000.0  27.1303  13.002547   5.0
# Online_Courses_Completed                 10000.0  10.0079   6.136726   0.0
# Assignment_Completion_Rate (%)           10000.0  74.9220  14.675437  50.0
# Exam_Score (%)                           10000.0  70.1889  17.649447  40.0
# Attendance_Rate (%)                      10000.0  75.0851  14.749251  50.0
# Time_Spent_on_Social_Media (hours/week)  10000.0  14.9365   9.022639   0.0
# Sleep_Hours_per_Night                    10000.0   6.9793   1.996965   4.0
#
#                                           25%   50%   75%    max
# Age                                      20.0  23.0  27.0   29.0
# Study_Hours_per_Week                     16.0  27.0  38.0   49.0
# Online_Courses_Completed                  5.0  10.0  15.0   20.0
# ...

# %%
#Check the number of unique values in the dataset
df.nunique()
# Out:
# Age                                        12
# Gender                                      3
# Study_Hours_per_Week                       45
# Preferred_Learning_Style                    4
# Online_Courses_Completed                   21
# Participation_in_Discussions                2
# Assignment_Completion_Rate (%)             51
# Exam_Score (%)                             61
# Attendance_Rate (%)                        51
# Use_of_Educational_Tech                     2
# Self_Reported_Stress_Level                  3
# Time_Spent_on_Social_Media (hours/week)    31
# Sleep_Hours_per_Night                       7
# Final_Grade                                 4
# dtype: int64

# %%
#Check the unique values in the gender column
df["Gender"].value_counts()
# Out:
# Gender
# Female    4846
# Male      4748
# Other      406
# Name: count, dtype: int64

# %%
#check of the mean of the age column
df.groupby("Gender")["Age"].mean()
# Out:
# Gender
# Female    23.485761
# Male      23.473463
# Other     23.458128
# Name: Age, dtype: float64

# %%
# Visualize the gender columns in the dataset
#from tkinter import font


plt.figure(figsize=(8, 4))

# Create label and adding percentage to the pie chart
df_gender_counts = df["Gender"].value_counts()
plt.pie(df_gender_counts, labels=df_gender_counts.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'orange', 'green'])

# Add title to the pie chart
plt.title("Gender Distribution", fontsize = 14, fontweight = "bold")

# Display the pie chart
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=9)
plt.show()

# %%
#check of the mean of the study hours per week column
df.groupby("Gender")["Study_Hours_per_Week"].mean()
# Out:
# Gender
# Female    27.234626
# Male      26.996209
# Other     27.453202
# Name: Study_Hours_per_Week, dtype: float64

# %%
# Visualize the study hours per week column in the dataset

# Set the figure size
plt.figure(figsize=(8, 4))

# Set Seaborn style for a better background
sns.set_style("darkgrid")  # Other options: "whitegrid", "ticks", "dark", "white"

# Create the bar plot
sns.barplot(x="Gender", y="Study_Hours_per_Week", data=df, palette="viridis", errorbar=None)

# Add title and labels with styling
plt.title("Study Hours vs Gender", fontsize=16, fontweight="bold", color="darkblue")
plt.xlabel("Gender", fontsize=12, fontweight="bold", color="black")
plt.ylabel("Study Hours per Week", fontsize=12, fontweight="bold", color="black")


# Display the bar plot

plt.show()

# %%
# check for the value count in the Sleep_Hours_per_Night  
Sleep_hours =df["Sleep_Hours_per_Night"].value_counts()

print(Sleep_hours)

Stress_level =df["Self_Reported_Stress_Level"].value_counts()
print(Stress_level)
# Out:
# Sleep_Hours_per_Night
# 8     1471
# 5     1451
# 4     1444
# 7     1428
# 6     1422
# 10    1410
# 9     1374
# Name: count, dtype: int64
# Self_Reported_Stress_Level
# Medium    5015
# Low       2966
# High      2019
# Name: count, dtype: int64

# %%
# Visualization of Sleep_Hours_per_Night  and Self_Reported_Stress_Level  in a subplot

# Set figure size
fig, axes = plt.subplots(1, 2, figsize = (14,5))


# create the first plot (histplot)
sns.histplot(df["Sleep_Hours_per_Night"], bins = 7,  color = 'purple', ax = axes[0])

# add title and labels for first plot
axes[0].set_title("Distribution of Sleep Hours", fontsize=16, fontweight="bold", color="darkblue")
axes[0].set_ylabel("Number of Student", fontsize=12, fontweight="bold", color="black")
axes[0].set_xlabel("Sleep Hours per Night", fontsize=12, fontweight="bold", color="black")
axes[0].grid(True)

# Creating the visual bar plot in the second plot
stress_counts = df["Self_Reported_Stress_Level"].value_counts().reset_index()
stress_counts.columns = ["Self_Reported_Stress_Level", "Count"]
# create the second plot (barplot)
sns.barplot(x = "Self_Reported_Stress_Level", y = "Count", data = stress_counts, palette="Set1", ax = axes[1])

# add title and labels for second plot
axes[1].set_title("Distribution of Self-Reported Stress Level", fontsize=16, fontweight="bold", color="darkblue")
axes[1].set_ylabel("Number of Student", fontsize=12, fontweight="bold", color="black")
axes[1].set_xlabel("Self-Reported Stress Level", fontsize=12, fontweight="bold", color="black")
axes[1].grid(True)


# display the bar plot
plt.tight_layout()
plt.show()

# %%
# Check for the value counts in the Preferred_Learning_Style column
df["Preferred_Learning_Style"].value_counts()
# Out:
# Preferred_Learning_Style
# Visual             2523
# Kinesthetic        2513
# Reading/Writing    2498
# Auditory           2466
# Name: count, dtype: int64

# %%
# Check for the value counts in percentage for the Preferred_Learning_Style column
df["Preferred_Learning_Style"].value_counts( normalize=True) * 100
# Out:
# Preferred_Learning_Style
# Visual             25.23
# Kinesthetic        25.13
# Reading/Writing    24.98
# Auditory           24.66
# Name: proportion, dtype: float64

# %%
# visualize the Preferred_Learning_Style column in the dataset

# set the figure size
plt.figure(figsize=(8, 4))

# define the values for the bar plot
df_learning_style_counts = df["Preferred_Learning_Style"].value_counts()

# create the bar plot
plt.bar(df_learning_style_counts.index, df_learning_style_counts.values, color=['skyblue', 'orange', 'green', 'brown'], label="Preferred Learning Style")

# add title and labels
plt.title("Preferred Learning Style", fontsize=16, fontweight="bold", color="darkblue")
plt.ylabel("Count", fontsize=12, fontweight="bold", color="black")
plt.xlabel("Learning Style", fontsize=12, fontweight="bold", color="black")
plt.xticks(rotation=45)

# display the bar plot
plt.show()

# %%
#Preferred Learning Style vs. Exam_Score (%)

# Set Seaborn style
sns.set_style("darkgrid")

# Set figure size
plt.figure(figsize=(8, 5))

# Define the order of grades (if necessary)
grade_order = ["A", "B", "C", "D"]
df["Final_Grade"] = pd.Categorical(df["Final_Grade"], categories=grade_order, ordered=True)

# Create the grouped bar plot
sns.barplot(x="Preferred_Learning_Style", 
            y="Exam_Score (%)",  # Use a numeric column for the y-axis
            hue="Gender",  # If gender-based grouping is needed
            data=df,  # Pass the dataframe explicitly
            palette="Set1",
            errorbar=None)  # Remove error bars

# Add title and labels
plt.title("Preferred Learning Style vs. Exam_Score (%)", fontsize=14, fontweight="bold")
plt.xlabel("Preferred Learning Style")
plt.ylabel("Exam_Score (%)")
plt.xticks(rotation=45)

# Adjust legend position
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Check for the value counts for the Study_Hours_per_Week and Time_Spent_on_Social_Media (hours/week) columns
df[["Study_Hours_per_Week", "Time_Spent_on_Social_Media (hours/week)"]].value_counts()
# Out:
# Study_Hours_per_Week  Time_Spent_on_Social_Media (hours/week)
# 37                    29                                         19
# 17                    25                                         18
# 41                    3                                          17
# 47                    7                                          16
# 42                    28                                         16
#                                                                  ..
#                       10                                          1
# 27                    19                                          1
# 12                    15                                          1
# 36                    20                                          1
# 14                    0                                           1
# Name: count, Length: 1394, dtype: int64

# %%
# Visualize the Study_Hours_per_Week and Time_Spent_on_Social_Media (hours/week) columns in the dataset

# Set the figure size
plt.figure(figsize=(8, 4))

# Create the scatter plot
plt.scatter(df["Study_Hours_per_Week"], df["Time_Spent_on_Social_Media (hours/week)"], color="red", label="Study Hours vs Time Spent on Social Media")

# Add title and labels
plt.title("Study Hours vs Time Spent on Social Media", fontsize=16, fontweight="bold", color="darkblue")
plt.xlabel("Study Hours per Week", fontsize=12, fontweight="bold", color="black")
plt.ylabel("Time Spent on Social Media (hours/week)", fontsize=12, fontweight="bold", color="black")

# Display the scatter plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=9)
plt.show()

# %%
# check the correlation of the time spent on social media and the study hours per week
df[["Study_Hours_per_Week", "Time_Spent_on_Social_Media (hours/week)"]].corr()
#df[["Time_Spent_on_Social_Media (hours/week)", "Study_Hours_per_Week"]].corr()
# Out:
#                                          Study_Hours_per_Week  \
# Study_Hours_per_Week                                  1.00000
# Time_Spent_on_Social_Media (hours/week)               0.01038
#
#                                          Time_Spent_on_Social_Media (hours/week)
# Study_Hours_per_Week                                                     0.01038
# Time_Spent_on_Social_Media (hours/week)                                  1.00000

# %%
# Check for the value counts in the Use_of_Educational_Tech column
tech = df["Use_of_Educational_Tech"].value_counts()

# Check for the value counts in percentage for the Use_of_Educational_Tech column
tech1 = df["Use_of_Educational_Tech"].value_counts( normalize=True) * 100


# Check for the value counts in online_courses_completed column
online_courses_completed = df["Online_Courses_Completed"].value_counts()

# Check for the value counts in percentage for the online_courses_completed column
online_courses_completed1 = df["Online_Courses_Completed"].value_counts( normalize=True) * 100

print(tech)
print(tech1)
print(online_courses_completed)
print(online_courses_completed1)
# Out:
# Use_of_Educational_Tech
# Yes    7022
# No     2978
# Name: count, dtype: int64
# Use_of_Educational_Tech
# Yes    70.22
# No     29.78
# Name: proportion, dtype: float64
# Online_Courses_Completed
# 0     526
# 17    516
# 5     507
# 1     505
# 18    499
# 20    492
# 8     489
# 15    487
# 2     480
# 19    476
# 16    474
# 12    472
# 6     470
# 4     467
# 9     466
# 10    457
# 14    457
# 11    454
# 13    453
# 3     432
# 7     421
# Name: count, dtype: int64
# Online_Courses_Completed
# 0     5.26
# 17    5.16
# 5     5.07
# 1     5.05
# 18    4.99
# 20    4.92
# 8     4.89
# 15    4.87
# 2     4.80
# 19    4.76
# 16    4.74
# 12    4.72
# 6     4.70
# 4     4.67
# 9     4.66
# 10    4.57
# 14    4.57
# 11    4.54
# 13    4.53
# 3     4.32
# 7     4.21
# Name: proportion, dtype: float64

# %%
# Use of Educational Tech vs. Online Courses Completed

# set the figure size
plt.figure(figsize=(8,5))

# Set Seaborn style for a better background
sns.set_style("darkgrid")  # Other options: "whitegrid", "ticks", "dark", "white"

# create the bar plot
sns.barplot(x=df["Use_of_Educational_Tech"], y=df["Online_Courses_Completed"], palette="viridis", errorbar=None)

# add title and labels with styling
plt.title("Use of Educational Tech vs. Online Courses Completed", fontsize=14, fontweight="bold")
plt.xlabel("Educational Tech Usage Level")
plt.ylabel("Online Courses Completed")
plt.xticks(rotation=45)

# display the bar plot
plt.show()

# %%
# visualize the Social Media Usage vs. Final Grade columns in the dataset

# Set the figure size
plt.figure(figsize=(8, 5))

# Set Seaborn style for a better background
sns.set_style("darkgrid")  # Other options: "whitegrid", "ticks", "dark", "white"

# Sort Final Grades (if they are not in order)
grade_order = ["A", "B", "C", "D"] # Define the order of grades


# Create the bar plot
sns.barplot(x=df["Time_Spent_on_Social_Media (hours/week)"], 
            y=df["Final_Grade"], 
            hue=df["Gender"], 
            palette="Set2", 
            errorbar=None, # Remove error bars
            order=grade_order)  # Set the order of grades

# Add title and labels with styling
plt.title("Social Media Time vs. Final Grade", fontsize=14, fontweight="bold")
plt.xlabel("Hours Spent on Social Media per Week")
plt.ylabel("Final Grade")
plt.grid(True)

# Display the bar plot
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Scatter Plot for Study Hours vs. Final Grade

# Set the figure size
plt.figure(figsize=(8, 5))


# Sort Final Grades (if they are not in order)
grade_order = ["A", "B", "C", "D"] # Define the order of grades

# Create a grouped bar chart
sns.barplot(x=df["Final_Grade"], 
            y=df["Study_Hours_per_Week"], 
            hue=df["Gender"], 
            palette="viridis", # Try "Set2", "viridis", or "coolwarm" for different effects
            errorbar=None,  # Remove error bars
            order=grade_order)  

# Add title and labels
plt.title("Study Hours vs. Final Grade", fontsize=14, fontweight="bold")
plt.xlabel("Final Grade")
plt.ylabel("Average Study Hours per Week")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Adjust legend position
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Selecting only the numerical columns
numerical_df = df.select_dtypes(include=[np.number])

# Compute correlation matrix
correlation_table1 = numerical_df.corr(method='spearman').fillna(0)  # Replace NaNs with 0

# Fix any NaN or Infinite values before plotting
correlation_table2 = correlation_table1.replace([np.inf, -np.inf], np.nan).fillna(0)

# Make sure we have a symmetric correlation matrix
correlation_table3 = correlation_table2 + correlation_table2.T - np.diag(correlation_table2.values.diagonal())



# Display the correlation table
print("Correlation Table:")
correlation_table3
# Out:
# Correlation Table:
#                                               Age  Study_Hours_per_Week  \
# Age                                      1.000000             -0.004147
# Study_Hours_per_Week                    -0.004147              1.000000
# Online_Courses_Completed                -0.009949              0.051536
# Assignment_Completion_Rate (%)          -0.012469              0.001764
# Exam_Score (%)                           0.003543              0.008057
# Attendance_Rate (%)                     -0.028291              0.015554
# Time_Spent_on_Social_Media (hours/week)  0.025284              0.020530
# Sleep_Hours_per_Night                    0.023897              0.021968
#
#                                          Online_Courses_Completed  \
# Age                                                     -0.009949
# Study_Hours_per_Week                                     0.051536
# Online_Courses_Completed                                 1.000000
# ...

# %%
# Create a heatmap
plt.figure(figsize=(14, 6), dpi=300)  # Increase figure size and resolution

sns.heatmap(
    correlation_table3,
    annot=True, 
    cmap='coolwarm', 
    vmin=-1, vmax=1, 
    center=0,
    mask = None,
    linewidths=1,
    fmt='.5f',
    annot_kws={"size": 12}  # Increase annotation size
)


# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.title("Correlation Heatmap")
plt.tight_layout()  # Ensure everything fits well
#plt.savefig("correlation_heatmap22.png", dpi = 300,bbox_inches="tight")  # Save the plot as an image
plt.show(block = True)
